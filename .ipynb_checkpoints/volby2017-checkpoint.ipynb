# %% [markdown]
# ## vizualizace parlamentních voleb ČR 2017
# data: vysledky_krajmesta

# %% [markdown]
# import libraries

# %%
from lxml import etree
import os
import pandas as pd
import xml.etree.ElementTree as ET
import numpy as np
from numpy import nan
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load and parse XML data

# %%
# datovy soubor 
#file_name = 'vysledky.xml' 
#base_path = os.path.dirname(os.path.realpath(__file__))
#xml_file = os.path.join(base_path, file_name)

# parse XML
#tree = ET.parse("/home/bob/Documents/python_projects/volby2017/vysledky.xml")
tree = ET.parse("./vysledky.xml")
root = tree.getroot()

# %%
#df = pd.DataFrame([])
#data = []

# %%
#okresu = len(root.getchildren())
#okresu = len(root.getchildren())
#
#okresu = len(root.findall('{http://www.volby.cz/ps/}KRAJ'))


# init np.array
data = np.full((15, 32), None)

# %%
# init nazvy sloupcu 
data[0,0] = "Kraj"
for strana in tree.iter(tag = "{http://www.volby.cz/ps/}STRANA"):
    data[0, int(strana.get("KSTRANA"))] = strana.get("NAZ_STR")
    # projít pouze jednu větev stromu! Nyní prochází celý strom.

# %%
# init data
for elem in tree.iter(tag = "{http://www.volby.cz/ps/}KRAJ"):
    data[int(elem.get("CIS_KRAJ")), 0] = elem.get("NAZ_KRAJ")
    for subelem in elem.iter(tag = "{http://www.volby.cz/ps/}STRANA"):
        for strana in subelem.iter(tag = "{http://www.volby.cz/ps/}HODNOTY_STRANA"):
            data[int(elem.get("CIS_KRAJ")), int(subelem.get("KSTRANA"))] = float(strana.get("PROC_HLASU"))

# %%
# data to df 
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.reindex(df.index.drop(0))
#df.fillna(value=nan, inplace=True)
df.fillna(0, inplace=True)

# %%
# úprava datasetu - strany nad 5 procent + přejmenování col a index
df_5proc = df.iloc[:,[0,1,4,7,8,15,20,21,24,29]]
df_5proc.columns = (['Kraj', 'ODS', 'CSSD', 'STAN', 'KSCM', 'CPS', 'TOP09', 'ANO2011', 'KDU-CSL', 'SPD'])
df_5proc = df_5proc.set_index('Kraj')

# %%
df_5proc
# Out:
#                    ODS  CSSD   STAN  KSCM    CPS  TOP09  ANO2011  KDU-CSL  \
# Kraj
# Hl. m. Praha     16.22  5.57   5.05  4.60  17.59  12.64    20.35     4.76
# Středočeský      12.93  6.63   8.07  7.21  12.08   6.33    28.66     3.01
# Jihočeský        12.12  7.30   4.57  9.32  10.51   5.30    28.86     5.38
# Plzeňský         12.09  7.97   4.85  8.65  10.01   4.82    30.98     3.49
# Karlovarský       8.83  6.98   5.28  8.15  10.04   3.68    35.42     2.36
# Ústecký           9.47  6.61   3.62  9.89   8.24   3.63    37.55     1.80
# Liberecký        10.28  5.65  12.82  6.69  11.42   4.22    29.83     2.05
# Královéhradecký  11.56  6.50   5.08  7.10  10.73   5.13    31.77     5.84
# Pardubický       10.96  7.47   4.97  7.74  10.51   4.20    30.81     6.81
# Vysočina          9.89  9.37   4.28  9.44   9.92   3.86    28.63     9.24
# Jihomoravský     11.88  8.44   3.63  8.04   9.11   4.51    27.40     8.97
# Olomoucký         8.92  7.44   4.44  8.78   8.49   3.24    31.39     8.26
# Zlínský           9.75  6.94   5.82  7.01   8.43   2.86    28.76    11.41
# Moravskoslezský   7.47  8.83   2.64  8.69   8.64   2.58    35.42     6.45
#
#                    SPD
# Kraj
# Hl. m. Praha      5.81
# Středočeský       9.00
# Jihočeský         9.85
# Plzeňský         10.56
# Karlovarský      12.47
# Ústecký          12.59
# Liberecký        10.95
# Královéhradecký  10.05
# Pardubický       10.14
# Vysočina          9.60
# Jihomoravský     11.65
# Olomoucký        13.54
# Zlínský          12.90
# Moravskoslezský  13.87

# %%
# Basic correlogram
# %matplotlib inline
sns.pairplot(df_5proc, kind = "reg")
plt.show()

# %%
# Calculate correlations
partaj = 'TOP09'
corr = df_5proc.corr()
corr1 = corr.T.sort_values(partaj, ascending=False).T
corr2 = corr1.sort_values(partaj, ascending=False)

# %%
# Heatmap
plt.yticks(rotation=0)
plt.xticks(rotation=90)
sns.heatmap(corr2, center=0, annot=True,
            linewidths=.5, 
            cmap="coolwarm", cbar_kws={"shrink": .5})
# color palettes https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
# Line Plot
partajLine = 'TOP09'
df_5proc_sorted = df_5proc.sort_values(partajLine, ascending = False)
df_5proc_sorted.plot(kind = 'line', cmap = "Set2", rot = 90, xticks = range(14), style='-')
